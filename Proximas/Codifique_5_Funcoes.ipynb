# %% [markdown]
# # Definição
# Uma coisa que é legal de evitar enquanto nós, programadores, estamos vendo aquelas letrinhas coloridas (e, às vezes, puxando os cabelos porque parece que tem hora que o pc não quer rodar), é a **repetição de trecho de código**

# %%
a = 10; b = 50
print(a+b)

a = 20; b = 60
print(a+b)

a = 30; b = 70
print(a+b)

a = 40; b = 80
print(a+b)

a = 50; b = 90
print(a+b)

# %% [markdown]
# Tem uma forma da gente, sommeliers de organização de letrinhas coloridas, deixar mais bonito o código?
#
# Para cortar a graça: sim, tem sim, são as chamadas **funções**
#
# Um exemplo seria refazer o "experimento" acima como uma dessas

# %%
# pra definir uma função, a gnt usa o comando def, vem de "define" ou definir
def soma(a,b):
  return a+b

print(soma(10, 50))

# também dá pra fazer o seguinte

def soma(a,b):
  print(a+b)

soma(10,50)

# %% [markdown]
# Agora, explicando umas coisas:
# * Essas coisas que a gnt coloca entre parenteses do lado do nome da função são chamadas de parâmetros e servem para passar valores pra dentro das funções;
#
# * não necessariamente as funções retornam um valor (aquele tal de "return" no primeiro exemplo faria isso, retornaria o valor);
#
# * a função nada mais é que um trecho de código que pode retornar ou não um valor a fim de evitar repetir código, então é possível utilizar tudo que foi visto até agora: lista, tupla, "loop" de repetição, condicional, tudo isso.

# %%
# dá pra fazer umas coisas bem doidas com funções também, por incrível que pareça
# como, por exemplo, retornar mais de um valor:

def soma_multiplicacao(a,b):
  return a+b, a*b

s, m = soma_multiplicacao(10, 50)
print(s, m)

# %% [markdown]
# Uma parada muito relevante quando se fala de função é **escopo de variável**.
# Primeiro, escopo tem o sentido de alvo, segundo o dicionário, mas no nosso contexto é, na verdade, um espaço.
#
# A ideia de ser um espaço é que, se eu declarar uma variável naquele espaço, ela só vai existir naquele espaço. Se eu tentar referenciar essa variável fora do espaço, ela não vai existir
#
# Dado esse contexto, também é possível usar uma variável **global**, que estaria presente meio que em todos os "espaços"

# %%
# É pra dar erro mesmo, não se assusta
def teste():
  existe = 1
  print(existe)
print(existe)

# %% [markdown]
# # Exercícios

# %% [markdown]
# Exercício 1 (Fácil - Aventura Espacial):
# História: Você é um astronauta em uma missão espacial. Durante a sua jornada, você precisa calcular o consumo médio de combustível da nave para garantir que haja combustível suficiente para a viagem de volta à Terra. Crie uma função chamada "consumo_combustivel" que receba a quantidade total de combustível consumido em litros e a distância percorrida em quilômetros. A função deve calcular e retornar o consumo médio de combustível (litros por quilômetro) com duas casas decimais.

# %% [markdown]
# Exercício 2 (Moderado - Caça ao Tesouro):
# História: Você é um caçador de tesouros em busca de uma recompensa escondida em uma ilha misteriosa. No entanto, para chegar ao tesouro, é necessário resolver um enigma. Crie uma função chamada "enigma" que receba três números inteiros como argumentos. A função deve retornar o menor valor entre os três números.

# %% [markdown]
# Exercício 3 (Moderado - Resgate na Floresta):
# História: Você é um aventureiro em uma expedição na floresta tropical. Em meio a densa vegetação, você encontra um pequeno vilarejo com pessoas amigáveis. Eles pedem sua ajuda para calcular a área de uma clareira circular onde realizam suas celebrações. Crie uma função chamada "area_clareira" que receba o raio da clareira em metros e retorne a área do local com duas casas decimais.

# %% [markdown]
# Exercício 4 (Difícil - Missão Submarina):
# História: Como um explorador submarino, você descobre um antigo artefato submerso que contém uma sequência de números. A fim de desvendar o mistério por trás dos números, você precisa criar uma função chamada "media_harmonica" que calcule e retorne a média harmônica de uma lista de números fornecida como argumento. A média harmônica é dada pela fórmula: n / (1/x1 + 1/x2 + ... + 1/xn), onde n é o número de elementos na lista e x1, x2, ..., xn são os elementos.

# %% [markdown]
# Exercício 5 (Difícil - Jornada Épica):
# História: Em uma jornada épica por terras desconhecidas, você se depara com um antigo pergaminho com instruções misteriosas. O pergaminho descreve uma sequência de passos codificados como "D" (direita) e "E" (esquerda). Crie uma função chamada "caminho_percorrido" que receba uma string contendo a sequência de passos e retorne a quantidade total de passos para a direita e para a esquerda, indicando o deslocamento líquido em cada direção.
